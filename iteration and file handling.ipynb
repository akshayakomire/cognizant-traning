# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
marks=[34,45,56,78,89,98,34]
print(marks)
# Out:
# [34, 45, 56, 78, 89, 98, 34]

# %%
name=["aksh","siri","thash","srav","sree"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# aksh
# siri
# thash
# srav
# sree

# %%
marks=[4,5,8,9,10,45,]
it=iter(marks)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 4
# 5
# 8
# 9
# 10
# 45

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen=numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file =open("demo,txt","w")
file.write("hello student")
file.close()

# %%
file =open("demo,txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hello student
